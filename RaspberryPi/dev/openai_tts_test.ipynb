# %%
import openai
import os
import io
import IPython.display as ipd
from pathlib import Path
from openai import OpenAI
from pydub import AudioSegment
from pydub.playback import play

key = os.environ.get('OPENAI_API_KEY')
openai.api_key = key

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Dustin\\Documents\\Github\\FindyBot5000\\RaspberryPi\\dev'

# %%
client = OpenAI()
speech_file_path = Path(os.getcwd()).parent / "assets" / "tts" / "speech.mp3"

# %%
response = client.audio.speech.create(
  model="tts-1",
  voice="onyx",
  input="Today is a wonderful day to build something people love!"
)

response.stream_to_file(speech_file_path)

# %%
speech_file_path2 = Path(os.getcwd()).parent / "assets" / "tts" / "speech2.mp3"
response = client.audio.speech.create(
  model="tts-1",
  voice="onyx",
  input="It's gonna be a good day!"
)

response.stream_to_file(speech_file_path)

# %%
speech_memory_buffer = io.BytesIO()
speech_memory_buffer.write(response.content)
#response.stream_to_file(speech_memory_buffer)
speech_memory_buffer.seek(0)
# Out:
# 0

# %%
ipd.Audio(speech_memory_buffer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Dustin\Documents\Github\FindyBot5000\RaspberryPi\dev\openai_tts_test.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dustin/Documents/Github/FindyBot5000/RaspberryPi/dev/openai_tts_test.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> ipd.Audio(speech_memory_buffer)
#
# File c:\Users\Dustin\miniconda3\envs\FindyBot5000\Lib\site-packages\IPython\lib\display.py:129, in Audio.__init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     127 if self.data is not None and not isinstance(self.data, bytes):
#     128     if rate is None:
# --> 129         raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     130     self.data = Audio._make_wav(data, rate, normalize)
#
# ...

# %%
ipd.Audio(speech_file_path, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
type(response)
# Out:
# openai._base_client.HttpxBinaryResponseContent

# %%
response.content

# %%
audio_stream = io.BytesIO(response.content)
audio = AudioSegment.from_mp3(audio_stream)
play(audio)

# %%
speech_file_path
# Out:
# WindowsPath('c:/Users/Dustin/Documents/Github/FindyBot5000/RaspberryPi/assets/tts/speech.mp3')
